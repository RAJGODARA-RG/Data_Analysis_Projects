# %% [markdown]
# Data file(CSV):- https://github.com/najirh/Python-Project-P2-New-York-AirBnb-Listing-2024/blob/main/datasets.csv

# %% [markdown]
# Step 1 - Importing all dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2- Reading CSV

# %%
data = pd.read_csv('/content/datasets.csv')

# %% [markdown]
# Step 3- Initial exploration

# %%
data.head(5)
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
data.shape
# Out:
# (20770, 22)

# %%
data[data['neighbourhood'].isnull()]
# Out:
#                  id                                               name  \
# 15913  4.704742e+07  Guest suite in New York · ★4.88 · 8 bedrooms ·...
# 15914  3.890630e+07  Loft in Brooklyn · ★4.71 · 1 bedroom · 1 bed ·...
# 15915  4.678660e+05  Rental unit in New York · ★4.90 · 1 bedroom · ...
# 15916  3.303301e+06  Loft in Brooklyn · ★4.89 · 1 bedroom · 1 bed ·...
# 15917  1.661685e+07  Rental unit in Brooklyn · ★4.81 · 1 bedroom · ...
# 15918  7.940000e+17  Rental unit in Brooklyn · ★4.80 · 2 bedrooms ·...
# 15919  4.810402e+07  Rental unit in New York · ★4.50 · Studio · 2 b...
#
#          host_id  host_name neighbourhood_group neighbourhood  latitude  \
# 15913  380290574      Karen           Manhattan           NaN       NaN
# 15914   51954926          K            Brooklyn           NaN       NaN
# 15915    2321870      David           Manhattan           NaN       NaN
# 15916   12385603       Anne            Brooklyn           NaN       NaN
# ...

# %% [markdown]
# Checking columns where value is null and dropping them

# %%
data.isnull().sum()
data.dropna()
# Out:
#                  id                                               name  \
# 0      1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# ...             ...                                                ...
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id           host_name neighbourhood_group       neighbourhood  \
# ...

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(12)

# %%
data[data.duplicated()]
# Out:
#                  id                                               name  \
# 6      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10     4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20736  7.990000e+17  Rental unit in New York · 2 bedrooms · 2 beds ...
# 20737  5.930000e+17  Rental unit in New York · ★4.79 · 2 bedrooms ·...
# 20738  9.230000e+17  Loft in New York · ★4.33 · 1 bedroom · 2 beds ...
# 20739  1.336161e+07  Rental unit in New York · ★4.89 · 2 bedrooms ·...
# 20740  5.119566e+07  Rental unit in New York · Studio · 1 bed · 1 bath
# 20741  2.523473e+07  Rental unit in New York · ★4.41 · 1 bedroom · ...
# 20742  3.339399e+06  Rental unit in New York · ★4.73 · 1 bedroom · ...
#
# ...

# %%
data.drop_duplicates(inplace =True)

# %% [markdown]
# Data analysis

# %%
data['price']
# Out:
# 0         55.0
# 1        144.0
# 2        187.0
# 3        120.0
# 4         85.0
#          ...
# 20765     45.0
# 20766    105.0
# 20767    299.0
# 20768    115.0
# 20769    102.0
# Name: price, Length: 20724, dtype: float64

# %%
sns.histplot(data=data, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data=data,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
data1 = data[data['price']<2500]

# %%
cnt = data1['price'].between(4000,10000).sum()
print(cnt)
# Out:
# 0

# %%
sns.boxplot(data=data1,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=data1,x='price',bins=100)
plt.ylabel("Cost frequency")
# Out:
# Text(0, 0.5, 'Cost frequency')

# %%
data1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
sns.histplot(data=data1,x='availability_365')
plt.title("Room availaibility throughout the year")
plt.ylabel('Number of BNB available')
# Out:
# Text(0, 0.5, 'Number of BNB available')

# %%
sns.scatterplot(data=data1,x='price',y='minimum_nights')
plt.ylabel('minimum stay')
# Out:
# Text(0, 0.5, 'minimum stay')

# %%
data1['minimum_nights'].describe()
# Out:
# count    20686.000000
# mean        28.568307
# std         33.584091
# min          1.000000
# 25%         30.000000
# 50%         30.000000
# 75%         30.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
data1.groupby('room_type')['price'].mean()
# Out:
# room_type
# Entire home/apt    214.877195
# Hotel room         302.609091
# Private room       109.847950
# Shared room        122.737931
# Name: price, dtype: float64

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
data1['price_per_bed'] = data1['price']/data1['beds']
# Out:
# /tmp/ipython-input-2921568047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['price_per_bed'] = data1['price']/data1['beds']

# %%
data1[['price_per_bed','price','beds']]
# Out:
#        price_per_bed  price  beds
# 0               55.0   55.0     1
# 1              144.0  144.0     1
# 2               93.5  187.0     2
# 3              120.0  120.0     1
# 4               85.0   85.0     1
# ...              ...    ...   ...
# 20765           45.0   45.0     1
# 20766           52.5  105.0     2
# 20767          299.0  299.0     1
# 20768          115.0  115.0     1
# 20769          102.0  102.0     1
#
# [20686 rows x 3 columns]

# %%
data1.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
#        longitude        room_type  price  ...  reviews_per_month  \
# ...

# %%
data1.groupby('neighbourhood_group')['price_per_bed'].mean()
# Out:
# neighbourhood_group
# Bronx             74.713639
# Brooklyn         100.098426
# Manhattan        142.399131
# Queens            76.850864
# Staten Island     67.728101
# Name: price_per_bed, dtype: float64

# %%
sns.barplot(data=data1,x='neighbourhood_group',y='price_per_bed',hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price_per_bed'>

# %%
sns.pairplot(data1,hue='price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=data1,x='longitude',y='latitude',hue= 'room_type')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
corr = data1[['price','minimum_nights']]
corr
# Out:
#        price  minimum_nights
# 0       55.0            30.0
# 1      144.0            30.0
# 2      187.0             2.0
# 3      120.0            30.0
# 4       85.0            30.0
# ...      ...             ...
# 20765   45.0            30.0
# 20766  105.0            30.0
# 20767  299.0            30.0
# 20768  115.0            30.0
# 20769  102.0             1.0
#
# [20686 rows x 2 columns]

# %%
corr = data1.corr(numeric_only=True)
corr
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.422573  0.009572   0.067537
# host_id                         0.422573  1.000000  0.012109   0.121957
# latitude                        0.009572  0.012109  1.000000   0.047005
# longitude                       0.067537  0.121957  0.047005   1.000000
# price                           0.042339 -0.011781  0.018365  -0.180180
# minimum_nights                 -0.073694 -0.072645  0.004312   0.024054
# number_of_reviews              -0.282996 -0.139679 -0.048061   0.005542
# reviews_per_month               0.138115  0.170679 -0.041816   0.042281
# calculated_host_listings_count -0.010741 -0.050268  0.069935  -0.072529
# availability_365                0.101576  0.083016 -0.005532   0.062812
# number_of_reviews_ltm           0.037414  0.100899 -0.041776   0.033428
# beds                            0.041145  0.057262 -0.070562   0.036665
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=corr,annot=True)
# Out:
# <Axes: >
